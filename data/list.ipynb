# %%
import pandas as pd
df=pd.read_csv('art_data.csv')
art_goods=df.to_dict(orient='records')
print(art_goods)
# Out:
# [{'Категорія': 'Фарби', 'Назва товару': 'Акрил Сонет 120мл', 'Вартість': 185, 'Артикул': 'PT-001', 'Статус наявності': 'В наявності'}, {'Категорія': 'Фарби', 'Назва товару': 'Олія Мастер-Класс 46мл', 'Вартість': 240, 'Артикул': 'PT-002', 'Статус наявності': 'В наявності'}, {'Категорія': 'Фарби', 'Назва товару': 'Гуаш Таір 40мл', 'Вартість': 65, 'Артикул': 'PT-003', 'Статус наявності': 'Закінчується'}, {'Категорія': 'Фарби', 'Назва товару': 'Акварель Ван Гог 12 кювет', 'Вартість': 890, 'Артикул': 'PT-004', 'Статус наявності': 'В наявності'}, {'Категорія': 'Фарби', 'Назва товару': 'Акрил глянцевий ROSA 75мл', 'Вартість': 145, 'Артикул': 'PT-005', 'Статус наявності': 'Під замовлення'}, {'Категорія': 'Фарби', 'Назва товару': 'Акварель Сонет 24 кольори', 'Вартість': 420, 'Артикул': 'PT-006', 'Статус наявності': 'В наявності'}, {'Категорія': 'Пензлі', 'Назва товару': 'Penзель білка круглий №4', 'Вартість': 95, 'Артикул': 'BR-001', 'Статус наявності': 'В наявності'}, {'Категорія': 'Пензлі',
# ...

# %%
df.head()
# Out:
#   Категорія               Назва товару  Вартість Артикул Статус наявності
# 0     Фарби          Акрил Сонет 120мл       185  PT-001      В наявності
# 1     Фарби     Олія Мастер-Класс 46мл       240  PT-002      В наявності
# 2     Фарби             Гуаш Таір 40мл        65  PT-003     Закінчується
# 3     Фарби  Акварель Ван Гог 12 кювет       890  PT-004      В наявності
# 4     Фарби  Акрил глянцевий ROSA 75мл       145  PT-005   Під замовлення
